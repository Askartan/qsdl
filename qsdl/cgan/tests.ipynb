# %%
import sys
from pathlib import Path
root = Path.cwd().parents[1]  # z qsdl/cgan → root repo
sys.path.insert(0, str(root))
from qsdl.cgan.rho import rho_from_params

# %%
import torch
from cgan import StateReconstructor

model = StateReconstructor()
x = torch.randn(4, 1, 128, 128)
params = model(x)
rho = rho_from_params(params, N=64)
print(params.shape, rho.shape)  # (4, 4160), (4, 64, 64)
# Out:
# torch.Size([4, 4160]) torch.Size([4, 64, 64])

# %%
import torch
param = torch.randn(4,4160)
test = rho_from_params(param, N=64)

test.ndim
# Out:
# 3

# %%
import h5py
import torch

with h5py.File(f"{root}/data/train_noisy_35.h5", 'r') as f:
    x = print(f.keys())
    # for key in f.keys():
        # print(list(f[key]))
        # print("\n")
    print(f['rhos_clean'].shape)
    print(f['wigner'][1].dtype)
    print(f['wigner_clean'].shape)
    for i in range(35):
        print(torch.trace(torch.from_numpy(f['rhos_clean'][i])))
# Out:
# <KeysViewHDF5 ['labels', 'metadata', 'rhos_clean', 'wigner', 'wigner_clean']>
# (35, 64, 64)
# float32
# (35, 128, 128)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.0000+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
# tensor(1.+0.j)
